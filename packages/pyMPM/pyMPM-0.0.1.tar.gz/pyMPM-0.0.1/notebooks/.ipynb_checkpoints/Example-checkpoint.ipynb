# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# /Users/chwala-c/code/pyMPM93

# %%
from MPM93 import MPM93
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-82b75efa7daa> in <module>()
# ----> 1 from MPM93 import MPM93
#
# ImportError: No module named MPM93

# %% [markdown]
# # Plot attenuation for dry air and air with 50% and 100% relative humidity

# %%
figsize(14,6)

f = arange(1,1000)

T = 15
P = 1013
RH_vec = [0, 50, 100]

for RH in RH_vec:
    A = MPM93(f, P, T, RH, 0, 0, 0, 'att')
    semilogy(f,A, label='RH ' + str(RH) + '%')

xlabel('f in GHz')
ylabel('A in db/km')
legend(loc=2)
grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bff605fa9dc9> in <module>()
# ----> 1 figsize(14,6)
#       2
#       3 f = arange(1,1000)
#       4
#       5 T = 15
#
# NameError: name 'figsize' is not defined

# %% [markdown]
# # Plot dispersive delay for dry air and air with 50% and 100% relative humidity

# %%
for RH in RH_vec:
    D = MPM93(f, P, T, RH, 0, 0, 0, 'del')
    plot(f,D, label='RH ' + str(RH) + '%')

xlabel('f in GHz')
ylabel('Dispersion delay in ps/km')
legend(loc=2)
grid()
